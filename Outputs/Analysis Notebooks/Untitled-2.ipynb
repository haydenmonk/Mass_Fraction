# %%
import pandas as pd

# %%
df=pd.read_csv('/scratch/group/p.phy260085.000/mass_fraction_hayden/Outputs/Ejection_Results/2033781_ejection_results.txt',header=None)

# %%
df.columns=['mass','result','t','particle_id']

# %%
df
# Out:
#            mass  result          t  particle_id
# 0       0.00003       1        0.0      1035428
# 1       0.00003       1        0.0      1035425
# 2       0.00003       1        0.0      1035416
# 3       0.00003       1        0.0      1035404
# 4       0.00003       1        0.0      1035418
# ...         ...     ...        ...          ...
# 629995  0.00003       1  9995000.0      1035422
# 629996  0.00003       1  9996000.0      1035422
# 629997  0.00003       1  9997000.0      1035422
# 629998  0.00003       1  9998000.0      1035422
# 629999  0.00003       1  9999000.0      1035422
#
# [630000 rows x 4 columns]
