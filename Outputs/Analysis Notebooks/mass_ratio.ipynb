# %%
import numpy as np

# %%
masses=np.array([0.00030027,
        0.00071206,
        0.00168856,
        0.00400422,
        0.0094955])

# %%
np.log10(masses)
# Out:
# array([-3.52248806, -3.14748341, -2.7724835 , -2.39748207, -2.02248216])

# %%
a=np.arange(1,5,1)

# %%
a
# Out:
# array([1, 2, 3, 4])

# %%
4%6
# Out:
# 4
